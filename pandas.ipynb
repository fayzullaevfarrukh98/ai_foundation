# %% [markdown]
# <a href="https://colab.research.google.com/github/fayzullaevfarrukh98/ai_foundation/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df.head(6) # default 5 rows
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       5
# 4     Audi       1
# 5  Hyundai       4

# %%
df.tail(-1 ) # default 5 rows
# Out:
#       cars  counts
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       5
# 4     Audi       1
# 5  Hyundai       4

# %%
df.shape
# Out:
# (6, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
df.describe() #numerical columns only
# Out:
#          counts
# count  6.000000
# mean   3.666667
# std    2.160247
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    7.000000

# %%
df.iloc[0:]
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       5
# 4     Audi       1
# 5  Hyundai       4

# %%
mydataset = {
    'cars':["BMW","Volvo","Ford","Tesla", "Audi", "Hyundai" ],
    'counts':[3, 7, 2, 5, 1, 4]
}

df = pd.DataFrame(mydataset)
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       5
# 4     Audi       1
# 5  Hyundai       4

# %%
df.loc[1:3,"cars", ]
# Out:
# 1    Volvo
# 2     Ford
# 3    Tesla
# Name: cars, dtype: object

# %%
df[df["counts"] >5]
# Out:
#     cars  counts
# 1  Volvo       7

# %%
# df.mean(numeric_only=True)
df["counts"].mean()
# Out:
# np.float64(3.6666666666666665)

# %%
df.sum()
# Out:
# cars      BMWVolvoFordTeslaAudiHyundai
# counts                              22
# dtype: object

# %%
df.min()
# Out:
# cars      Audi
# counts       1
# dtype: object

# %%
df.max()
# Out:
# cars      Volvo
# counts        7
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    3.5
# dtype: float64

# %%
df.count()
# Out:
# cars      6
# counts    6
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    2.160247
# dtype: float64

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna(how="all")
# Out:
#     cars  counts
# 0    BMW     3.0
# 1  Volvo     7.0
# 3   None     5.0
# 4   Audi     NaN
# 5   None     4.0

# %%
data_with_missing = {
    "cars":["BMW","Volvo",None,None, "Audi", None ],
    "counts":[3, 7, None, 5, None, 4]
}
df_missing = pd.DataFrame(data_with_missing)
print(df_missing)
# Out:
#     cars  counts
# 0    BMW     3.0
# 1  Volvo     7.0
# 2   None     NaN
# 3   None     5.0
# 4   Audi     NaN
# 5   None     4.0

# %%
df_missing.fillna({"cars": "unknown", "counts": 0})
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2  unknown     0.0
# 3  unknown     5.0
# 4     Audi     0.0
# 5  unknown     4.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.to_excel("test.xlsx")

# %%
df = pd.read_excel("test.xlsx")
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Series => 1D
cars = pd.Series(["BMW", "Tesla", "Ferrari"])
print(cars)
# Out:
# 0        BMW
# 1      Tesla
# 2    Ferrari
# dtype: object

# %%
cars_series = data_with_missing['cars']
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, None, 'Audi', None]
